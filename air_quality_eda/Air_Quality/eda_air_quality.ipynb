# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df0 = pd.read_csv("Air_Quality.csv")
df=df0.copy()

# %%
print(f"This data has {df.shape} shape, {df.size} size and {df.isnull().sum().sum()} Null values.")
# Out:
# This data has (825, 38) shape, 31350 size and 4446 Null values.

# %%
df.head()
# Out:
#     CBSA Core Based Statistical Area Pollutant       Trend Statistic  \
# 0  10420                   Akron, OH        O3               4th Max
# 1  10420                         NaN     PM2.5  Weighted Annual Mean
# 2  10420                         NaN     PM2.5       98th Percentile
# 3  10420                         NaN       SO2       99th Percentile
# 4  10500                  Albany, GA     PM2.5  Weighted Annual Mean
#
#    Number of Trend Sites    1990     1991     1992     1993     1994  ...  \
# 0                      2    0.09    0.101    0.087    0.093    0.086  ...
# 1                      3     NaN      NaN      NaN      NaN      NaN  ...
# 2                      3     NaN      NaN      NaN      NaN      NaN  ...
# 3                      1  161.00  183.000  181.000  209.000  132.000  ...
# 4                      1     NaN      NaN      NaN      NaN      NaN  ...
#
#      2013   2014    2015   2016    2017    2018    2019    2020    2021   2022
# ...

# %%
df.tail()
# Out:
#       CBSA Core Based Statistical Area Pollutant       Trend Statistic  \
# 820  49700               Yuba City, CA       NO2           Annual Mean
# 821  49700                         NaN       NO2       98th Percentile
# 822  49700                         NaN        O3               4th Max
# 823  49700                         NaN     PM2.5  Weighted Annual Mean
# 824  49700                         NaN     PM2.5       98th Percentile
#
#      Number of Trend Sites    1990   1991   1992    1993    1994  ...   2013  \
# 820                      1  17.000  17.00  17.00  17.000  16.000  ...  10.00
# 821                      1  70.000  70.00  70.00  70.000  65.000  ...  52.00
# 822                      1   0.076   0.08   0.09   0.078   0.089  ...   0.06
# 823                      1     NaN    NaN    NaN     NaN     NaN  ...   8.20
# 824                      1     NaN    NaN    NaN     NaN     NaN  ...  25.00
#
#        2014    2015    2016    2017    2018    2019    2020    2021    2022
# ...

# %%
df.sample(5)
# Out:
#       CBSA Core Based Statistical Area Pollutant       Trend Statistic  \
# 44   12100                         NaN     PM2.5       98th Percentile
# 312  25540                         NaN     PM2.5  Weighted Annual Mean
# 149  17220              Clarksburg, WV     PM2.5  Weighted Annual Mean
# 392  29620    Lansing-East Lansing, MI        O3               4th Max
# 556  38060                         NaN     PM2.5       98th Percentile
#
#      Number of Trend Sites   1990   1991   1992   1993   1994  ...    2013  \
# 44                       1    NaN    NaN    NaN    NaN    NaN  ...  22.000
# 312                      1    NaN    NaN    NaN    NaN    NaN  ...   7.700
# 149                      1    NaN    NaN    NaN    NaN    NaN  ...   8.800
# 392                      1  0.081  0.083  0.083  0.078  0.078  ...   0.064
# 556                      4    NaN    NaN    NaN    NaN    NaN  ...  20.000
#
#        2014    2015    2016    2017    2018    2019    2020    2021    2022
# ...

# %%
df.columns
# Out:
# Index(['CBSA', 'Core Based Statistical Area', 'Pollutant', 'Trend Statistic',
#        'Number of Trend Sites', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
df['Trend Statistic'].unique()
# Out:
# array(['4th Max', 'Weighted Annual Mean', '98th Percentile',
#        '99th Percentile', '2nd Max', 'Annual Mean', 'Max 3-Month Average'],
#       dtype=object)

# %% [markdown]
# 4th Max: This refers to the fourth highest value in a dataset. It can be used to identify extreme events or outliers without focusing solely on the absolute maximum, which might be atypical.
#
# Weighted Annual Mean: This is a calculation where the mean of a dataset is weighted based on certain factors, typically time periods. For example, the annual mean of a pollutant might be weighted by the number of days in each month to give a more accurate representation of exposure over the entire year.
#
# 98th Percentile: This is the value below which 98% of the data points fall. It gives an idea of the upper end of the typical range of values, excluding extreme outliers. Similarly, the 99th Percentile would be the value below which 99% of the data points fall.
#
# 2nd Max: This simply refers to the second highest value in a dataset. It can be used along with the maximum to understand the distribution of extreme values.
#
# Annual Mean: This is the average of all data points within a year. It provides a simple and overall picture of the typical value throughout the year.
#
# Max 3-Month Average: This is the highest average value calculated over any three consecutive months within a year. It helps identify periods of relatively high exposure compared to the whole year.
#
# These metrics are used in various ways depending on the specific context. For example, air quality standards might be based on annual means or percentiles, while risk assessments might consider extreme events like the 4th max or the max 3-month average.

# %%
df.groupby('Pollutant')['Trend Statistic'].value_counts(dropna=False).sort_values(ascending=False)
# Out:
# Pollutant  Trend Statistic
# O3         4th Max                 205
# PM2.5      98th Percentile         195
#            Weighted Annual Mean    195
# SO2        99th Percentile          58
# NO2        Annual Mean              55
# PM10       2nd Max                  44
# NO2        98th Percentile          40
# CO         2nd Max                  31
# Pb         Max 3-Month Average       2
# Name: count, dtype: int64

# %%
df[df['Trend Statistic'] == '4th Max']
# Out:
#       CBSA        Core Based Statistical Area Pollutant Trend Statistic  \
# 0    10420                          Akron, OH        O3         4th Max
# 6    10580        Albany-Schenectady-Troy, NY        O3         4th Max
# 12   10740                                NaN        O3         4th Max
# 16   10900  Allentown-Bethlehem-Easton, PA-NJ        O3         4th Max
# 19   11020                        Altoona, PA        O3         4th Max
# ..     ...                                ...       ...             ...
# 803  49180                                NaN        O3         4th Max
# 807  49340                   Worcester, MA-CT        O3         4th Max
# 812  49620                                NaN        O3         4th Max
# 816  49660  Youngstown-Warren-Boardman, OH-PA        O3         4th Max
# 822  49700                                NaN        O3         4th Max
#
#      Number of Trend Sites   1990   1991   1992   1993   1994  ...   2013  \
# ...

# %%
df.groupby('CBSA')['Pollutant'].value_counts(dropna=False).sort_values(ascending=False)
# Out:
# CBSA   Pollutant
# 10420  PM2.5        2
# 25420  PM2.5        2
# 26380  PM2.5        2
# 26090  PM2.5        2
# 41740  NO2          2
#                    ..
# 27060  O3           1
# 26900  O3           1
#        PM10         1
#        SO2          1
# 49700  O3           1
# Name: count, Length: 590, dtype: int64

# %%
for i in range(1999,2023):
    i=str(i)
    print(f"In year {i}; Pollutants and its sum are {df.groupby('Pollutant')[i].sum().sort_values(ascending=False)}")
# Out:
# In year 1999; Pollutants and its sum are Pollutant
# SO2      5206.000
# NO2      3477.000
# PM10     2923.400
# CO        119.000
# O3         16.878
# Pb          0.100
# PM2.5       0.000
# Name: 1999, dtype: float64
# In year 2000; Pollutants and its sum are Pollutant
# PM2.5    9268.700
# SO2      4791.000
# NO2      3267.000
# PM10     2778.300
# CO        109.200
# O3         15.643
# Pb          0.100
# Name: 2000, dtype: float64
# In year 2001; Pollutants and its sum are Pollutant
# PM2.5    9302.800
# SO2      4550.000
# NO2      3234.000
# PM10     2703.400
# CO         98.300
# O3         15.896
# Pb          0.100
# Name: 2001, dtype: float64
# In year 2002; Pollutants and its sum are Pollutant
# PM2.5    9027.400
# SO2      4280.000
# NO2      3102.000
# PM10     2597.200
# CO         90.400
# O3         16.843
# Pb          0.100
# Name: 2002, dtype: float64
# In year 2003; Pollutants and its sum are Pollutant
# PM2.5    8237.700
# SO2      4303.000
# ...

# %%
df.columns
# Out:
# Index(['CBSA', 'Core Based Statistical Area', 'Pollutant', 'Trend Statistic',
#        'Number of Trend Sites', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
df['Core Based Statistical Area'].ffill(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CBSA                         825 non-null    int64
#  1   Core Based Statistical Area  825 non-null    object
#  2   Pollutant                    825 non-null    object
#  3   Trend Statistic              825 non-null    object
#  4   Number of Trend Sites        825 non-null    int64
#  5   1990                         435 non-null    float64
#  6   1991                         435 non-null    float64
#  7   1992                         435 non-null    float64
#  8   1993                         435 non-null    float64
#  9   1994                         435 non-null    float64
#  10  1995                         435 non-null    float64
#  11  1996                         435 non-null    float64
#  12  1997                         435 non-null    float64
# ...

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.isnull())
plt.show()

# %%
df.describe().T
# Out:
#                        count          mean           std        min  \
# CBSA                   825.0  30450.048485  11754.076622  10420.000
# Number of Trend Sites  825.0      1.815758      1.656114      1.000
# 1990                   435.0     35.421317     58.457105      0.000
# 1991                   435.0     34.893938     57.778307      0.009
# 1992                   435.0     33.326637     56.256311      0.013
# 1993                   435.0     31.945421     52.228817      0.007
# 1994                   435.0     31.519699     49.852901      0.021
# 1995                   435.0     28.194032     43.570414      0.026
# 1996                   435.0     26.212821     40.915698      0.011
# 1997                   435.0     26.249244     41.208988      0.000
# 1998                   435.0     26.121766     42.295988      0.000
# 1999                   435.0     26.993972     42.781475      0.000
# 2000                   825.0     24.521143     29.044172      0.000
# ...

# %%
df.select_dtypes(include='object').describe().T
# Out:
#                             count unique  \
# Core Based Statistical Area   825    279
# Pollutant                     825      7
# Trend Statistic               825      7
#
#                                                                top freq
# Core Based Statistical Area  New York-Newark-Jersey City, NY-NJ-PA    8
# Pollutant                                                    PM2.5  390
# Trend Statistic                                    98th Percentile  235

# %%
#df.column_name.str.split(',', expand=True)

# %%
for i in range(1990,2000):
    i=str(i)
    sns.boxplot(df[i])

# %%
for i in range(1990,2000):
    i=str(i)
    sns.histplot(df[i])

# %%
for i in range(2000,2022):
    i=str(i)
    sns.histplot(df[i])

# %%
for i in range(1990,2000):
    i=str(i)
    df[i].fillna(df[i].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CBSA                         825 non-null    int64
#  1   Core Based Statistical Area  825 non-null    object
#  2   Pollutant                    825 non-null    object
#  3   Trend Statistic              825 non-null    object
#  4   Number of Trend Sites        825 non-null    int64
#  5   1990                         825 non-null    float64
#  6   1991                         825 non-null    float64
#  7   1992                         825 non-null    float64
#  8   1993                         825 non-null    float64
#  9   1994                         825 non-null    float64
#  10  1995                         825 non-null    float64
#  11  1996                         825 non-null    float64
#  12  1997                         825 non-null    float64
# ...

# %%
for i in range(1990,2000):
    i=str(i)
    sns.histplot(df[i])

# %%
for i in range(1990,2023):
    i=str(i)
    sns.histplot(data=df[i], bins= 10, kde=True)

# %%
sns.histplot(df['1990'], bins= 10, kde=True) #whis=1.5
# Out:
# <Axes: xlabel='1990', ylabel='Count'>

# %%
sns.histplot(df['2021'], bins= 10, kde=True)
# Out:
# <Axes: xlabel='2021', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['CBSA', 'Core Based Statistical Area', 'Pollutant', 'Trend Statistic',
#        'Number of Trend Sites', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
df.plot(lw=2,
          marker=".",
          subplots=True,
          layout=(-1, 4),
          figsize=(15, 10),
          markersize=4);

# %%
df.columns
# Out:
# Index(['CBSA', 'Core Based Statistical Area', 'Pollutant', 'Trend Statistic',
#        'Number of Trend Sites', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
df.drop(['Trend Statistic','Number of Trend Sites'], axis=1,inplace=True)

# %%
df.head()
# Out:
#     CBSA Core Based Statistical Area Pollutant        1990        1991  \
# 0  10420                   Akron, OH        O3    0.090000    0.101000
# 1  10420                   Akron, OH     PM2.5   35.421317   34.893938
# 2  10420                   Akron, OH     PM2.5   35.421317   34.893938
# 3  10420                   Akron, OH       SO2  161.000000  183.000000
# 4  10500                  Albany, GA     PM2.5   35.421317   34.893938
#
#          1992        1993        1994        1995        1996  ...    2013  \
# 0    0.087000    0.093000    0.086000    0.092000    0.091000  ...   0.059
# 1   33.326637   31.945421   31.519699   28.194032   26.212821  ...   9.700
# 2   33.326637   31.945421   31.519699   28.194032   26.212821  ...  24.000
# 3  181.000000  209.000000  132.000000  123.000000  133.000000  ...  23.000
# 4   33.326637   31.945421   31.519699   28.194032   26.212821  ...  10.000
#
#     2014    2015   2016    2017    2018    2019    2020    2021   2022
# ...

# %%
sns.countplot(x = "Pollutant", data=df);

# %%
for i in range(1999,2023):
    i=str(i)
    print(f"In year {df.groupby('Pollutant')[i].sum()}")
# Out:
# In year Pollutant
# CO        119.000
# NO2      3477.000
# O3         16.878
# PM10     2923.400
# PM2.5       0.000
# Pb          0.100
# SO2      5206.000
# Name: 1999, dtype: float64
# In year Pollutant
# CO        109.200
# NO2      3267.000
# O3         15.643
# PM10     2778.300
# PM2.5    9268.700
# Pb          0.100
# SO2      4791.000
# Name: 2000, dtype: float64
# In year Pollutant
# CO         98.300
# NO2      3234.000
# O3         15.896
# PM10     2703.400
# PM2.5    9302.800
# Pb          0.100
# SO2      4550.000
# Name: 2001, dtype: float64
# In year Pollutant
# CO         90.400
# NO2      3102.000
# O3         16.843
# PM10     2597.200
# PM2.5    9027.400
# Pb          0.100
# SO2      4280.000
# Name: 2002, dtype: float64
# In year Pollutant
# CO         83.800
# NO2      3073.000
# O3         15.573
# PM10     2704.000
# PM2.5    8237.700
# Pb          0.300
# SO2      4303.000
# Name: 2003, dtype: float64
# In year Pollutant
# CO         83.400
# ...

# %%
len(df.columns)
# Out:
# 38

# %%
a = df.iloc[:, :13]
b = df.iloc[:, 13:26]
c = df.iloc[:, 26:]

# %%
plt.figure(figsize=(15,5))
sns.heatmap(a.select_dtypes("number").corr(), annot = True, cmap="viridis",)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,5))
sns.heatmap(b.select_dtypes("number").corr(), annot = True, cmap="viridis",)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,5))
sns.heatmap(c.select_dtypes("number").corr(), annot = True, cmap="viridis",)
# Out:
# <Axes: >

# %%
sns.pairplot(df)
