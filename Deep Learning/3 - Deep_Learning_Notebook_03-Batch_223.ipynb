# %% [markdown]
# # Classification

# %% [markdown]
# <span class="girk">We have a dataset in which there are details of a bank's customers and the target variable is a binary variable reflecting the fact whether the customer left the bank (closed his account) or he continues to be a customer.</span>

# %% [markdown]
# ![binary.png](attachment:binary.png)

# %% [markdown]
# ## Import  libraries & data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
# %matplotlib notebook
plt.rcParams["figure.figsize"] = (12, 6)
# plt.rcParams['figure.dpi'] = 100
sns.set_style("whitegrid")
import warnings

warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
# ilgili kütüphanelerin tümü
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, average_precision_score
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv("Churn_Modelling.csv", index_col='RowNumber')
df.head()
#Tenure:Number of years for which the customer has been with the bank
#NumOfProducts :Number of bank products the customer is utilising
#Binary flag 1 if the customer closed account with bank and 0 if the customer is retained
#"RowNumber" sütunu indeks olarak belirleniyor
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1              0.000              1          1               1
# 2          83807.860              1          0               1
# 3         159660.800              3          1               0
# 4              0.000              2          0               0
# 5         125510.820              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1               101348.880       1
# 2               112542.580       0
# 3               113931.570       1
# 4                93826.630       0
# 5                79084.100       0

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.isnull().sum().any()
# Out:
# False

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                     count         mean       std          min          25%  \
# CustomerId      10000.000 15690940.569 71936.186 15565701.000 15628528.250
# CreditScore     10000.000      650.529    96.653      350.000      584.000
# Age             10000.000       38.922    10.488       18.000       32.000
# Tenure          10000.000        5.013     2.892        0.000        3.000
# Balance         10000.000    76485.889 62397.405        0.000        0.000
# NumOfProducts   10000.000        1.530     0.582        1.000        1.000
# HasCrCard       10000.000        0.706     0.456        0.000        0.000
# IsActiveMember  10000.000        0.515     0.500        0.000        0.000
# EstimatedSalary 10000.000   100090.240 57510.493       11.580    51002.110
# Exited          10000.000        0.204     0.403        0.000        0.000
#
#                          50%          75%          max
# CustomerId      15690738.000 15753233.750 15815690.000
# CreditScore          652.000      718.000      850.000
# Age                   37.000       44.000       92.000
# Tenure                 5.000        7.000       10.000
# Balance            97198.540   127644.240   250898.090
# NumOfProducts          1.000        2.000        4.000
# HasCrCard              1.000        1.000        1.000
# IsActiveMember         1.000        1.000        1.000
# EstimatedSalary   100193.915   149388.247   199992.480
# Exited                 0.000        0.000        1.000

# %%
df.drop(['CustomerId', 'Surname'], axis=1, inplace=True)

# %%
df.Exited.value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
value_counts = df['Exited'].value_counts()

plt.bar(value_counts.index, value_counts.values);

# %%
df.hist(figsize=(15, 12), bins=15);

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='viridis');

# %%
numerical_df = df.select_dtypes(include=[np.number])
plt.figure(figsize=(16, 12))
sns.heatmap(numerical_df.corr(), annot=True, cmap='viridis');

# %%
df.corr(numeric_only=True)['Exited'][:-1].sort_values().plot.barh()
# Out:
# <Axes: >

# %%
numerical_df = df.select_dtypes(include=[np.number])
correlation_series = numerical_df.corr()['Exited'][:-1].sort_values()
correlation_series.plot.barh();

# %%
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#            CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# RowNumber
# 1                  619   42       2      0.000              1          1
# 2                  608   41       1  83807.860              1          0
# 3                  502   42       8 159660.800              3          1
# 4                  699   39       1      0.000              2          0
# 5                  850   43       2 125510.820              1          1
#
#            IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# RowNumber
# 1                       1       101348.880       1              False
# 2                       1       112542.580       0              False
# 3                       0       113931.570       1              False
# 4                       0        93826.630       0              False
# 5                       1        79084.100       0              False
#
#            Geography_Spain  Gender_Male
# RowNumber
# 1                    False        False
# 2                     True        False
# 3                    False        False
# 4                    False        False
# 5                     True        False

# %% [markdown]
# ## Preprocessing of Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
X = df.drop('Exited', axis=1)
y = df['Exited'].values
seed = 42
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    stratify=y,
                                                    test_size=0.1,
                                                    random_state=seed)

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ![Structure-of-machine-learning-model.png](attachment:Structure-of-machine-learning-model.png)

# %% [markdown]
# ## Modelling & Model Performance

# %% [markdown]
# ### without class_weight

# %%
X_train.shape
# Out:
# (9000, 11)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, BatchNormalization
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score

# %%
from tensorflow.keras.optimizers import Adam

# %%
# tf.random.set_seed(seed = 1)
model = Sequential()

model.add(Dense(64, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(32, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(1, activation="sigmoid"))

opt = Adam(learning_rate=0.002)
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])

# Recall — the percentage of positive cases you caught
# Recall, false negative’in gözardı edilemez olduğu durumlarda önemli bir metrik. recall = TP / TP +FN
# Recall’a bakma sebebimiz tamamiyle paydadaki false negative’ler, yani hesabına devam ettiği tahmin edilen ve hesabını kapatan insanlar.

# %%
early_stop = EarlyStopping(monitor="val_loss",
                           mode="auto",
                           verbose=1,
                           patience=90)

# %%
model.fit(x=X_train,
          y=y_train,
          validation_split=.1,
          batch_size=32,
          epochs=500,
          verbose=1,
          callbacks=[early_stop])
# Out:
# Epoch 1/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - Recall: 0.3474 - loss: 0.6104 - val_Recall: 0.0000e+00 - val_loss: 0.4651
# Epoch 2/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.2205 - loss: 0.4308 - val_Recall: 0.5028 - val_loss: 0.3470
# Epoch 3/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.3661 - loss: 0.3923 - val_Recall: 0.5414 - val_loss: 0.3701
# Epoch 4/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - Recall: 0.3770 - loss: 0.3705 - val_Recall: 0.5967 - val_loss: 0.3256
# Epoch 5/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.4079 - loss: 0.3661 - val_Recall: 0.5138 - val_loss: 0.3212
# Epoch 6/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - Recall: 0.3878 - loss: 0.3785 - val_Recall: 0.5249 - val_loss: 0.3229
# Epoch 7/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.4193 - loss: 0.3625 - val_Recall: 0.6243 - val_loss: 0.3045
# Epoch 8/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - Recall: 0.4327 - loss: 0.3665 - val_Recall: 0.5635 - val_loss: 0.3063
# Epoch 9/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.4627 - loss: 0.3497 - val_Recall: 0.4862 - val_loss: 0.3209
# Epoch 10/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.4424 - loss: 0.3534 - val_Recall: 0.6188 - val_loss: 0.3256
# Epoch 11/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.4381 - loss: 0.3509 - val_Recall: 0.5359 - val_loss: 0.3141
# Epoch 12/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.4304 - loss: 0.3560 - val_Recall: 0.5359 - val_loss: 0.3082
# Epoch 13/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.
500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5828 - loss: 0.2892 - val_Recall: 0.6022 - val_loss: 0.3399
# Epoch 105/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5495 - loss: 0.2858 - val_Recall: 0.5083 - val_loss: 0.3510
# Epoch 106/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.5525 - loss: 0.2837 - val_Recall: 0.5912 - val_loss: 0.3488
# Epoch 107/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5935 - loss: 0.2963 - val_Recall: 0.5691 - val_loss: 0.3386
# Epoch 108/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5765 - loss: 0.2846 - val_Recall: 0.5856 - val_loss: 0.3425
# Epoch 109/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5774 - loss: 0.2931 - val_Recall: 0.5304 - val_loss: 0.3446
# Epoch 110/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.6023 - loss: 0.2883 - val_Recall: 0.5801 - val_loss: 0.3429
# Epoch 111/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5790 - loss: 0.2963 - val_Recall: 0.6133 - val_loss: 0.3248
# Epoch 112/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5550 - loss: 0.2945 - val_Recall: 0.5525 - val_loss: 0.3399
# Epoch 113/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5778 - loss: 0.2922 - val_Recall: 0.5912 - val_loss: 0.3342
# Epoch 114/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5617 - loss: 0.2863 - val_Recall: 0.5414 - val_loss: 0.3434
# Epoch 115/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - Recall: 0.5897 - loss: 0.2791 - val_Recall: 0.5580 - val_loss: 0.3412
# Epoch 116/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - Recall: 0.5612 - loss: 0.2982 - val_Recall: 0.5691 - val_loss: 0.3477
# Epoch 117/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.5732 - loss: 0.2895 - val_Recall: 0.5967 - val_loss: 0.3349
# Epoch 118/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - Recall: 0.5893 - loss: 0.2801 - val_Recall: 0.5525 - val_loss: 0.3754
# Epoch 119/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5763 - loss: 0.2897 - val_Recall: 0.5635 - val_loss: 0.3640
# Epoch 120/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5866 - loss: 0.2836 - val_Recall: 0.5525 - val_loss: 0.3575
# Epoch 121/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5811 - loss: 0.2784 - val_Recall: 0.6077 - val_loss: 0.3364
# Epoch 122/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5827 - loss: 0.2885 - val_Recall: 0.4972 - val_loss: 0.3684
# Epoch 123/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.5475 - loss: 0.2945 - val_Recall: 0.6077 - val_loss: 0.3468
# Epoch 124/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - Recall: 0.5970 - loss: 0.2852 - val_Recall: 0.5304 - val_loss: 0.3649
# Epoch 125/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.5478 - loss: 0.3011 - val_Recall: 0.5193 - val_loss: 0.3488
# Epoch 125: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 8)              │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,341 (48.21 KB)
#  Trainable params: 4,033 (15.75 KB)
#  Non-trainable params: 240 (960.00 B)
#  Optimizer params: 8,068 (31.52 KB)

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.head()
# Out:
#    Recall  loss  val_Recall  val_loss
# 0   0.253 0.530       0.000     0.465
# 1   0.252 0.429       0.503     0.347
# 2   0.346 0.400       0.541     0.370
# 3   0.389 0.383       0.597     0.326
# 4   0.411 0.372       0.514     0.321

# %%
loss_df.plot();

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# [[752  44]
#  [116  88]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90       796
#            1       0.67      0.43      0.52       204
#
#     accuracy                           0.84      1000
#    macro avg       0.77      0.69      0.71      1000
# weighted avg       0.83      0.84      0.83      1000

# %% [markdown]
# ![ROC.JPG](attachment:ROC.JPG)

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for model

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# roc curve, sınıflandırma performansını gösterir
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.6183599041624751

# %% [markdown]
# ### with class_weigth

# %%
model = Sequential()

model.add(Dense(64, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(32, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(1, activation="sigmoid"))

opt = Adam(learning_rate=0.002)
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                  classes=np.unique(y_train),
                                                  y=y_train)

class_weights = {0: class_weights[0], 1: class_weights[1]}
class_weights
# Out:
# {0: 0.6278777731268314, 1: 2.454991816693944}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model.fit(x=X_train,
          y=y_train,
          validation_split=.1,
          batch_size=32,
          epochs=500,
          verbose=1,
          callbacks=[early_stop],
          class_weight=class_weights)
# Out:
# Epoch 1/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - Recall: 0.6299 - loss: 0.7108 - val_Recall: 0.4862 - val_loss: 0.5124
# Epoch 2/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - Recall: 0.7157 - loss: 0.5782 - val_Recall: 0.7956 - val_loss: 0.4343
# Epoch 3/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7460 - loss: 0.5353 - val_Recall: 0.7348 - val_loss: 0.4449
# Epoch 4/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7548 - loss: 0.5045 - val_Recall: 0.8066 - val_loss: 0.4690
# Epoch 5/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.7786 - loss: 0.4932 - val_Recall: 0.8287 - val_loss: 0.4656
# Epoch 6/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7638 - loss: 0.4874 - val_Recall: 0.8508 - val_loss: 0.4812
# Epoch 7/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7650 - loss: 0.4769 - val_Recall: 0.8453 - val_loss: 0.4742
# Epoch 8/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.7802 - loss: 0.4889 - val_Recall: 0.7790 - val_loss: 0.4127
# Epoch 9/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7515 - loss: 0.4686 - val_Recall: 0.8287 - val_loss: 0.4963
# Epoch 10/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7708 - loss: 0.4723 - val_Recall: 0.8122 - val_loss: 0.4326
# Epoch 11/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.7470 - loss: 0.4752 - val_Recall: 0.8343 - val_loss: 0.4425
# Epoch 12/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7693 - loss: 0.4822 - val_Recall: 0.8398 - val_loss: 0.4529
# Epoch 13/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7617 - loss: 0.4828 - val_Recall: 0.8287 - val_loss: 0.4549
# Epoch 14/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.8059 - loss: 0.4508 - val_Recall: 0.8453 - val_loss: 0.4792
# Epoch 15/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7604 - loss: 0.4825 - val_Recall: 0.7624 - val_loss: 0.4129
# Epoch 16/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7597 - loss: 0.4810 - val_Recall: 0.8011 - val_loss: 0.4262
# Epoch 17/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7714 - loss: 0.4599 - val_Recall: 0.8177 - val_loss: 0.4441
# Epoch 18/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7752 - loss: 0.4716 - val_Recall: 0.8177 - val_loss: 0.4583
# Epoch 19/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.7757 - loss: 0.4635 - val_Recall: 0.8343 - val_loss: 0.4609
# Epoch 20/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7883 - loss: 0.4511 - val_Recall: 0.7790 - val_loss: 0.4256
# Epoch 21/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7723 - loss: 0.4672 - val_Recall: 0.8287 - val_loss: 0.4876
# Epoch 22/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Recall: 0.7738 - loss: 0.4625 - val_Recall: 0.7956 - val_loss: 0.4052
# Epoch 23/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7709 - loss: 0.4637 - val_Recall: 0.8122 - val_loss: 0.4278
# Epoch 24/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.7874 - loss: 0.4557 - val_Recall: 0.8508 - val_loss: 0.4551
# Epoch 25/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Recall: 0.
500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - Recall: 0.8318 - loss: 0.4066 - val_Recall: 0.7956 - val_loss: 0.4462
# Epoch 88/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.8264 - loss: 0.3999 - val_Recall: 0.7845 - val_loss: 0.4500
# Epoch 89/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - Recall: 0.8281 - loss: 0.3979 - val_Recall: 0.8453 - val_loss: 0.4641
# Epoch 90/500
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.8274 - loss: 0.4071 - val_Recall: 0.7845 - val_loss: 0.4207
# Epoch 90: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot();

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# [[642 154]
#  [ 60 144]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.81      0.86       796
#            1       0.48      0.71      0.57       204
#
#     accuracy                           0.79      1000
#    macro avg       0.70      0.76      0.72      1000
# weighted avg       0.83      0.79      0.80      1000

# %% [markdown]
# ![ROC.JPG](attachment:ROC.JPG)

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for model

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# roc curve, sınıflandırma performansını gösterir
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
average_precision_score(y_test, y_pred_proba)   #0.692983743350624
# Out:
# 0.6447512861590723

# %% [markdown]
# ## Final Model and Model Deployment

# %%
import pickle

pickle.dump(scaler, open("scaler_churn", 'wb'))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
scaler = MinMaxScaler().fit(X)

# %%
X_scaled = scaler.transform(X)

# %%
model = Sequential()

model.add(Dense(64, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(32, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(BatchNormalization())  
model.add(Dense(1, activation="sigmoid"))

opt = Adam(learning_rate=0.001)

model.compile(optimizer=opt,
              loss="binary_crossentropy",
              metrics=["Recall"])

# %%
model.fit(x=X_scaled,
          y=y,
          callbacks=[early_stop],
          batch_size=32,
          validation_split = 0.1,
          epochs=500,
          verbose=1,
          class_weight=class_weights)
# Out:
# Epoch 1/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - Recall: 0.5065 - loss: 0.7337 - val_Recall: 0.1564 - val_loss: 0.5674
# Epoch 2/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.6177 - loss: 0.6367 - val_Recall: 0.5531 - val_loss: 0.5681
# Epoch 3/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.6700 - loss: 0.6058 - val_Recall: 0.6089 - val_loss: 0.5349
# Epoch 4/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.6703 - loss: 0.5693 - val_Recall: 0.6927 - val_loss: 0.5534
# Epoch 5/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.7341 - loss: 0.5327 - val_Recall: 0.6983 - val_loss: 0.5239
# Epoch 6/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.7409 - loss: 0.5227 - val_Recall: 0.7151 - val_loss: 0.5282
# Epoch 7/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.7602 - loss: 0.4955 - val_Recall: 0.7151 - val_loss: 0.4908
# Epoch 8/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.7653 - loss: 0.4999 - val_Recall: 0.6648 - val_loss: 0.4929
# Epoch 9/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.7375 - loss: 0.4921 - val_Recall: 0.6648 - val_loss: 0.4982
# Epoch 10/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - Recall: 0.7643 - loss: 0.4820 - val_Recall: 0.6927 - val_loss: 0.5161
# Epoch 11/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.7546 - loss: 0.4853 - val_Recall: 0.7430 - val_loss: 0.5600
# Epoch 12/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.7686 - loss: 0.4903 - val_Recall: 0.6816 - val_loss: 0.4776
# Epoch 13/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.7467 - loss: 0.4838 - val_Recall: 0.7430 - val_loss: 0.5034
# Epoch 14/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.7711 - loss: 0.4703 - val_Recall: 0.6760 - val_loss: 0.4785
# Epoch 15/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - Recall: 0.
500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.7959 - loss: 0.4268 - val_Recall: 0.7263 - val_loss: 0.4864
# Epoch 78/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.8195 - loss: 0.4082 - val_Recall: 0.7039 - val_loss: 0.4881
# Epoch 79/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.8481 - loss: 0.4081 - val_Recall: 0.7039 - val_loss: 0.4949
# Epoch 80/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.8190 - loss: 0.4090 - val_Recall: 0.7151 - val_loss: 0.4837
# Epoch 81/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.8034 - loss: 0.4140 - val_Recall: 0.7039 - val_loss: 0.5204
# Epoch 82/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.8016 - loss: 0.4179 - val_Recall: 0.7318 - val_loss: 0.5180
# Epoch 83/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.8319 - loss: 0.4163 - val_Recall: 0.6760 - val_loss: 0.4720
# Epoch 84/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.8215 - loss: 0.4089 - val_Recall: 0.7207 - val_loss: 0.4979
# Epoch 85/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.8375 - loss: 0.4070 - val_Recall: 0.6425 - val_loss: 0.4731
# Epoch 86/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.8131 - loss: 0.4144 - val_Recall: 0.7039 - val_loss: 0.4923
# Epoch 87/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.8259 - loss: 0.4170 - val_Recall: 0.6648 - val_loss: 0.4821
# Epoch 88/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - Recall: 0.8132 - loss: 0.4098 - val_Recall: 0.7039 - val_loss: 0.5330
# Epoch 89/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.8117 - loss: 0.4014 - val_Recall: 0.7263 - val_loss: 0.5215
# Epoch 90/500
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - Recall: 0.8334 - loss: 0.4124 - val_Recall: 0.7151 - val_loss: 0.5032
# Epoch 90: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot();

# %%
loss, recall = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("recall : ", recall)
# Out:
# loss :  0.4218015670776367
# recall :  0.8676470518112183

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# [[631 165]
#  [ 27 177]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.79      0.87       796
#            1       0.52      0.87      0.65       204
#
#     accuracy                           0.81      1000
#    macro avg       0.74      0.83      0.76      1000
# weighted avg       0.87      0.81      0.82      1000

# %%
from tensorflow.keras.saving import save_model

save_model(model, 'model_churn.keras')

# %% [markdown]
# ### Prediction

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
single_customer = df.drop('Exited', axis=1).iloc[0]
single_customer
# Out:
# CreditScore                619
# Age                         42
# Tenure                       2
# Balance                  0.000
# NumOfProducts                1
# HasCrCard                    1
# IsActiveMember               1
# EstimatedSalary     101348.880
# Geography_Germany        False
# Geography_Spain          False
# Gender_Male              False
# Name: 1, dtype: object

# %%
single_customer = scaler.transform(single_customer.values.reshape(-1, 11))
single_customer
# Out:
# array([[0.538     , 0.32432432, 0.2       , 0.        , 0.        ,
#         1.        , 1.        , 0.50673489, 0.        , 0.        ,
#         0.        ]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y_pred =(model.predict(single_customer) > 0.5).astype("int32")
y_pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# array([[1]])

# %%
df["Exited"].iloc[0]
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Comparison with ML

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model=LogisticRegression(class_weight='balanced')
log_model.fit(X_train, y_train)
y_pred = log_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[558 238]
#  [ 67 137]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.70      0.79       796
#            1       0.37      0.67      0.47       204
#
#     accuracy                           0.69      1000
#    macro avg       0.63      0.69      0.63      1000
# weighted avg       0.79      0.69      0.72      1000

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(class_weight='balanced')
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[766  30]
#  [118  86]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       796
#            1       0.74      0.42      0.54       204
#
#     accuracy                           0.85      1000
#    macro avg       0.80      0.69      0.72      1000
# weighted avg       0.84      0.85      0.84      1000
