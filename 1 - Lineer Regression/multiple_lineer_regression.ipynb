# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (8, 4)
import warnings
warnings.filterwarnings('ignore')

# %%
# y = b0 + b1X1 + b2X2 + b3X3    multiple linear regress.

# %% [markdown]
# ### **Read Data Set**

# %%
df = pd.read_csv('Advertising.csv')
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# ## **Data Preparation- EDA**

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
import missingno as msno

# %%
msno.matrix(df);

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull())
plt.show()

# %%
df.sort_values(by="sales", ascending=False)
# Out:
#         TV  radio  newspaper  sales
# 175  276.9   48.9       41.8   27.0
# 183  287.6   43.0       71.8   26.2
# 198  283.6   42.0       66.2   25.5
# 98   289.7   42.3       51.2   25.4
# 147  243.2   49.0       44.3   25.4
# ..     ...    ...        ...    ...
# 108   13.1    0.4       25.6    5.3
# 78     5.4   29.9        9.4    5.3
# 8      8.6    2.1        1.0    4.8
# 155    4.1   11.6        5.7    3.2
# 130    0.7   39.6        8.7    1.6
#
# [200 rows x 4 columns]

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
# pip install summarytools

# %%
from summarytools import dfSummary
dfSummary(df, is_collapsible=True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-2440" onclick = "coll_toggle_2440()">Show Summary - df</button>
#     <div class="st-content" id="cont-2440">
#       <style type="text/css">
# #T_ca144 thead>tr>th {
#   text-align: left;
# }
# #T_ca144_row0_col0, #T_ca144_row1_col0, #T_ca144_row2_col0, #T_ca144_row3_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_ca144_row0_col1, #T_ca144_row1_col1, #T_ca144_row2_col1, #T_ca144_row3_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_ca144_row0_col2, #T_ca144_row1_col2, #T_ca144_row2_col2, #T_ca144_row3_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_ca144_row0_col3, #T_ca144_row1_col3, #T_ca144_row2_col3, #T_ca144_row3_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_ca144_row0_col4, #T_ca144_row1_col4, #T_ca144_row2_col4, #T_ca144_row3_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_ca144_row0_col5, #T_ca144_row1_col5, #T_ca144_row2_col5, #T_ca144_row3_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_ca144">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 200 x 4<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_ca144_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_ca144_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_ca144_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_ca144_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_ca144_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_ca144_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ca144_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ca144_row0_col1" class="data row0 col1" ><strong>TV</strong><br>[float64]</td>
#       <td id="T_ca144_row0_col2" class="data row0 col2" >Mean (sd) : 147.0 (85.9)<br>min < med < max:<br>0.7 < 149.8 < 296.4<br>IQR (CV) : 144.4 (1.7)</td>
#       <td id="T_ca144_row0_col3" class="data row0 col3" >190 distinct values</td>
#       <td id="T_ca144_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_ca144_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ca144_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ca144_row1_col1" class="data row1 col1" ><strong>radio</strong><br>[float64]</td>
#       <td id="T_ca144_row1_col2" class="data row1 col2" >Mean (sd) : 23.3 (14.8)<br>min < med < max:<br>0.0 < 22.9 < 49.6<br>IQR (CV) : 26.5 (1.6)</td>
#       <td id="T_ca144_row1_col3" class="data row1 col3" >167 distinct values</td>
#       <td id="T_ca144_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_ca144_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ca144_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ca144_row2_col1" class="data row2 col1" ><strong>newspaper</strong><br>[float64]</td>
#       <td id="T_ca144_row2_col2" class="data row2 col2" >Mean (sd) : 30.6 (21.8)<br>min < med < max:<br>0.3 < 25.8 < 114.0<br>IQR (CV) : 32.4 (1.4)</td>
#       <td id="T_ca144_row2_col3" class="data row2 col3" >172 distinct values</td>
#       <td id="T_ca144_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_ca144_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ca144_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ca144_row3_col1" class="data row3 col1" ><strong>sales</strong><br>[float64]</td>
#       <td id="T_ca144_row3_col2" class="data row3 col2" >Mean (sd) : 14.0 (5.2)<br>min < med < max:<br>1.6 < 12.9 < 27.0<br>IQR (CV) : 7.0 (2.7)</td>
#       <td id="T_ca144_row3_col3" class="data row3 col3" >121 distinct values</td>
#       <td id="T_ca144_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_ca144_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>
#
#     </div>
#     <style>
#     #btn-2440.st-collapsible {
#       background-color: white;
#       color: #444;
#       cursor: pointer;
#       padding: 1.5rem 2rem;
#       width: 100%;
#       text-align: left;
#       outline: none;
#       font-size: 14px;
#       border-top-left-radius: 0.375rem;
#       border-top-right-radius: 0.375rem;
#       border: 1px solid #dee2e6;
#       border-bottom: none;
#       font-weight: 500;
#     }
#
#     #btn-2440.active {
#       background-color: #e7f1ff;
#       color: #0c63e4;
#     }
#
#     #cont-2440.st-content {
#       padding: 0 10px;
#       background-color: white;
#       max-height: 0;
#       overflow: hidden;
#       transition: max-height 0.2s ease-out;
#       border: 1px solid #dee2e6;
#       border-top: none;
#     }
#
#     #cont-2440.st-content .active {
#       border: 1px solid #dee2e6;
#       border-bottom-left-radius: 0.375rem;
#       border-bottom-right-radius: 0.375rem;
#     }
#
#     #btn-2440.st-collapsible:after {
#       content: '';
#       background-image: url("data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 16 16' fill='%23212529'%3e%3cpath fill-rule='evenodd' d='M1.646 4.646a.5.5 0 0 1 .708 0L8 10.293l5.646-5.647a.5.5 0 0 1 .708.708l-6 6a.5.5 0 0 1-.708 0l-6-6a.5.5 0 0 1 0-.708z'/%3e%3c/svg%3e");
#       color: #444;
#       font-weight: bold;
#       float: right;
#       margin-left: 5px;
#       height: 1.5em;
#       width:  1.5rem;
#       background-repeat: no-repeat;
#       transition: transform 0.2s ease-in-out;
#     }
#
#     #btn-2440.active:after {
#       content: '';
#       background-image: url("data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 16 16' fill='%230c63e4'%3e%3cpath fill-rule='evenodd' d='M1.646 4.646a.5.5 0 0 1 .708 0L8 10.293l5.646-5.647a.5.5 0 0 1 .708.708l-6 6a.5.5 0 0 1-.708 0l-6-6a.5.5 0 0 1 0-.708z'/%3e%3c/svg%3e");
#       transform: rotate(180deg);
#     }
#     </style><script>
#     function coll_toggle_2440(){
#         var coll = document.getElementById("btn-2440");
#         var content = document.getElementById("cont-2440");
#         coll.classList.toggle("active");
#         if (content.style.maxHeight){
#           content.style.maxHeight = null;
#           coll.innerHTML = "Show Summary - df";
#         } else {
#           content.style.maxHeight = content.scrollHeight + "px";
#           coll.innerHTML = "Hide Summary - df";
#         }
#     }
#
#     </script>

# %%
# mean ve Std değerleenini birbirine yakınlığının outlier tespitindeki önemi hakkında bir örnek

print ( np.mean([100,110,120,115]))
print ( np.std([100,110,120,115]))
# Out:
# 111.25
# 7.39509972887452

# %%
print ( np.mean([100,110,120,700]))
print ( np.std([100,110,120,700]))
# Out:
# 257.5
# 255.57533136044253

# %%
sns.pairplot(df);

# %%
corr = df.corr()
sns.heatmap(corr, annot=True);

# %%
from scipy.stats import skew

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# skewness tespiti için bir döngü
for i in df.drop(columns = "sales").columns:
    print(i, skew(df[i]))
# sales sütunu haricindeki tüm feature ların skewness degerini hesplar
# Out:
# TV -0.06932836662244649
# radio 0.0934668451108453
# newspaper 0.8879959753085498

# %% [markdown]
# - -0.5 ile + 0.5 arasındaki skewness degerlerinde dagılımın kabaca simetrik oldugu kabul edilebilir

# %%
for j in df.drop(columns = "sales").columns:     #"sales" sütunu dataframe'den kaldırılıyor
    g = sns.distplot(df[j], color= "b", label= "Skewness : %.2f"%(df[j].skew()))   #  j sütununa ait veri dağılımı grafiği çiziliyor. grafiğin üzerinde gösterilen etiketi oluşturur. Etiket, o sütunun çarpıklık değerini (skewness) içerir
    g = g.legend(loc= "best")   #  grafiğin üzerine eklenen etiketin konumunu en iyi yere yerleştirmes
    plt.show()

# %% [markdown]
# ### **Train-Test Split**

# %%
# pip install scikit-learn

# %%
X = df.drop(columns='sales')  # df[['TV', 'radio', 'newspaper']]
y = df['sales']

# %%
from sklearn.model_selection import train_test_split   # randomly train and test set splitted

# %% [markdown]
# X_train: Eğitim veri setinin özelliklerini (features) içerir.
#
# X_test: Test veri setinin özelliklerini (features) içerir.
#
# y_train: Eğitim veri setinin etiketlerini (labels/targets) içerir.
#
# y_test: Test veri setinin etiketlerini (labels/targets) içerir.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![x_train_x test.gif](<attachment:x_train_x test.gif>)

# %%
print("X Train features shape: {}\ny Train features shape: {}\nX Test features shape : {}\nY Test features shape : {}".format
      (X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X Train features shape: (140, 3)
# y Train features shape: (140,)
# X Test features shape : (60, 3)
# Y Test features shape : (60,)

# %%
print("X Train shape: ", X_train.shape)
print("y Target shape: ", y_train.shape)
print("X Test shape: ", X_test.shape)
print("y Target shape: ", y_test.shape)
# Out:
# X Train shape:  (140, 3)
# y Target shape:  (140,)
# X Test shape:  (60, 3)
# y Target shape:  (60,)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([16.5653963 , 21.18822792, 21.55107058, 10.88923816, 22.20231988,
#        13.35556872, 21.19692502,  7.35028523, 13.27547079, 15.12449511,
#         9.01443026,  6.52542825, 14.30205991,  8.97026042,  9.45679576,
#        12.00454351,  8.91549403, 16.15619251, 10.29582883, 18.72473553,
#        19.76821818, 13.77469028, 12.49638908, 21.53501762,  7.60860741,
#         5.6119801 , 20.91759483, 11.80627665,  9.08076637,  8.51412012,
#        12.17604891,  9.9691939 , 21.73008956, 12.77770578, 18.1011362 ,
#        20.07590796, 14.26202556, 20.93826535, 10.83938827,  4.38190607,
#         9.51332406, 12.40486324, 10.17045434,  8.09081363, 13.16388427,
#         5.2243552 ,  9.28893833, 14.09330719,  8.69024497, 11.66119763,
#        15.71848432, 11.63156862, 13.35360735, 11.1531472 ,  6.33636845,
#         9.76157954,  9.4195714 , 24.25516546,  7.69519137, 12.15317572])

# %%
model.coef_ # modelin katsayilarini verir (TV: 0.04, radio:0.199, newspaper:0.006)
# Out:
# array([0.04405928, 0.1992875 , 0.00688245])

# %%
model.feature_names_in_
# Out:
# array(['TV', 'radio', 'newspaper'], dtype=object)

# %%
model.intercept_
# Out:
# 2.7089490925159065

# %%
# herhangi bir satırdaki degerler için tahmin yapalım..manuel olarak y_pred hesapladım
sum(X_test.loc[95]*model.coef_) + model.intercept_
# Out:
# 16.565396297434837

# %%
my_dict = {"actual": y_test, "prediction": y_pred, "residual":(y_test - y_pred)}

comparing = pd.DataFrame(my_dict)
comparing
# Out:
#      actual  prediction  residual
# 95     16.9   16.565396  0.334604
# 15     22.4   21.188228  1.211772
# 30     21.4   21.551071 -0.151071
# 158     7.3   10.889238 -3.589238
# 128    24.7   22.202320  2.497680
# 115    12.6   13.355569 -0.755569
# 69     22.3   21.196925  1.103075
# 170     8.4    7.350285  1.049715
# 174    11.5   13.275471 -1.775471
# 45     14.9   15.124495 -0.224495
# 66      9.5    9.014430  0.485570
# 182     8.7    6.525428  2.174572
# 165    11.9   14.302060 -2.402060
# 78      5.3    8.970260 -3.670260
# 186    10.3    9.456796  0.843204
# 177    11.7   12.004544 -0.304544
# 56      5.5    8.915494 -3.415494
# 152    16.6   16.156193  0.443807
# 82     11.3   10.295829  1.004171
# 68     18.9   18.724736  0.175264
# 124    19.7   19.768218 -0.068218
# 16     12.5   13.774690 -1.274690
# 148    10.9   12.496389 -1.596389
# 93     22.2   21.535018  0.664982
# 65      9.3    7.608607  1.691393
# 60      8.1    5.611980  2.488020
# 84     21.7   20.917595  0.782405
# 67     13.4   11.806277  1.593723
# 125    10.6    9.080766  1.519234
# 132     5.7    8.514120 -2.814120
# 9      10.6   12.176049 -1.576049
# 18     11.3    9.969194  1.330806
# 55     23.7   21.730090  1.969910
# 75      8.7   12.777706 -4.077706
# 150    16.1   18.101136 -2.001136
# 104    20.7   20.075908  0.624092
# 135    11.6   14.262026 -2.662026
# 137    20.8   20.938265 -0.138265
# 164    11.9   10.839388  1.060612
# 76      6.9    4.381906  2.518094
# 79     11.0    9.513324  1.486676
# 197    12.8   12.404863  0.395137
# 38     10.1   10.170454 -0.070454
# 24      9.7    8.090814  1.609186
# 122    11.6   13.163884 -1.563884
# 195     7.6    5.224355  2.375645
# 29     10.5    9.288938  1.211062
# 19     14.6   14.093307  0.506693
# 143    10.4    8.690245  1.709755
# 86     12.0   11.661198  0.338802
# 114    14.6   15.718484 -1.118484
# 173    11.7   11.631569  0.068431
# 5       7.2   13.353607 -6.153607
# 126     6.6   11.153147 -4.553147
# 117     9.4    6.336368  3.063632
# 73     11.0    9.761580  1.238420
# 140    10.9    9.419571  1.480429
# 98     25.4   24.255165  1.144835
# 172     7.6    7.695191 -0.095191
# 96     11.7   12.153176 -0.453176

# %%
result_sample = comparing.head(25)

# %%
result_sample.plot(kind= "bar", figsize = (15,9))
plt.show()

# %% [markdown]
# ### **Error Metrics**

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
R2_score = r2_score(y_test, y_pred)
R2_score
# Out:
# 0.8609466508230368

# %%
# MAE hesabı
mae = mean_absolute_error(y_test, y_pred)  # ne kadar dusuk o kadar basarili
mae
# Out:
# 1.5116692224549086

# %%
# MSE hesabı
mse = mean_squared_error(y_test, y_pred)  # ne kadar dusuk o kadar basarili
mse
# Out:
# 3.79679723671522

# %%
# root mean squared error (RMSE)
rmse = np.sqrt(mean_squared_error(y_test, y_pred)) # ne kadar dusuk okadar iyi, hatalari daha fazla cezalandirir, outlierlara karsi cok hassas.
rmse
# Out:
# 1.9485372043446387

# %%
# Mean error metric

sales_mean = df["sales"].mean()
sales_mean
# Out:
# 14.0225

# %%
# MAE Hata Oranı - "0' a yakın olması iyi bir tahmin modeli oldugunu gösterir"
mae / sales_mean
# Out:
# 0.10780311802138767

# %%
# RMSE Hata Orani
rmse / sales_mean   # outlier a daha hassas oldugu icin mae ye gore kayip var
# Out:
# 0.138957903679418

# %% [markdown]
# ### **Adjusted R2 Score**

# %% [markdown]
# n = gözlem sayım (data noktası sayısı)
#
# p = feature
#
# Adjusted R2 = 1 - [(1 - R2) * (n - 1) / (n - p - 1)]

# %%
def adj_r2(y_test, y_pred, df):
    r2 = r2_score(y_test, y_pred)    #R2 scor
    n = df.shape[0]      # number of observations gözlem
    p =df.shape[1]-1    # number of indep. variable = feature
    adj_r2 = 1 - (1-r2)*(n-1)/(n-p-1)
    return adj_r2

# %%
adj_r2(y_test, y_pred, df)
# Out:
# 0.8588182832335934

# %%
# önceki r2 degerine yakın çıktı. çünkü zaten 3 feature vardı. alt örnekte feature sayısını abartıı vererek adjusted etkisini görelim
def adj_r2(y_test, y_pred, df):
    r2 = r2_score(y_test, y_pred)    #R2 scor
    n = df.shape[0]      # number of observations gözlem
    p =100    # number of indep. variable = feature
    adj_r2 = 1 - (1-r2)*(n-1)/(n-p-1)
    return adj_r2

# %%
adj_r2(y_test, y_pred, df)
# Out:
# 0.7204887223614578

# %%
# bir görüşe göre, her eklenen feature ,için 10-15 gözlem satırı daha eklenmelidir

# %% [markdown]
# ### **Model Evaluation**

# %%
# Error metricleri hesaplayan ve yazan kod blogu
def eval_metric(actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    print("Model testing performance: ")
    print("---------------------------")
    print(f"R2_score \t: {R2_score}")
    print(f"MAE \t\t: {mae}")
    print(f"MSE \t\t: {mse}")
    print(f"RMSE \t\t: {rmse}")

# %%
eval_metric(y_test, y_pred)
# Out:
# Model testing performance:
# ---------------------------
# R2_score 	: 0.8609466508230368
# MAE 		: 1.5116692224549086
# MSE 		: 3.79679723671522
# RMSE 		: 1.9485372043446387

# %%
# Overfitting kontrolü için train data daki R2 yi bulalım ve yukardak test R2 (0.86) ile karşılaştıralım
# X_train degerlerini prediction yapacağız
y_train_pred = model.predict(X_train)

# %%
eval_metric(y_train, y_train_pred)
# Out:
# Model testing performance:
# ---------------------------
# R2_score 	: 0.9055159502227753
# MAE 		: 1.1581502948072526
# MSE 		: 2.4793551789057866
# RMSE 		: 1.574596830590544

# %%
residuals = y_test- y_pred

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(x=y_test, y=residuals)
plt.xlabel("Sales")
plt.ylabel("Residuals")
plt.axhline(y=0, color = "r", linestyle = "--")
plt.show()

# %%
import scipy.stats as stats

# %%
stats.probplot(residuals, dist="norm", plot=plt)
# Out:
# ((array([-2.27390067, -1.91302992, -1.70135682, -1.54640086, -1.42160977,
#          -1.31571014, -1.2228056 , -1.13940346, -1.06325419, -0.99281837,
#          -0.92699283, -0.86495764, -0.80608503, -0.74988229, -0.69595441,
#          -0.64397882, -0.5936878 , -0.54485575, -0.49729007, -0.45082415,
#          -0.40531215, -0.36062492, -0.31664678, -0.27327293, -0.23040741,
#          -0.18796131, -0.14585132, -0.10399849, -0.06232713, -0.02076376,
#           0.02076376,  0.06232713,  0.10399849,  0.14585132,  0.18796131,
#           0.23040741,  0.27327293,  0.31664678,  0.36062492,  0.40531215,
#           0.45082415,  0.49729007,  0.54485575,  0.5936878 ,  0.64397882,
#           0.69595441,  0.74988229,  0.80608503,  0.86495764,  0.92699283,
#           0.99281837,  1.06325419,  1.13940346,  1.2228056 ,  1.31571014,
#           1.42160977,  1.54640086,  1.70135682,  1.91302992,  2.27390067]),
#   array([-6.15360735, -4.5531472 , -4.07770578, -3.67026042, -3.58923816,
#          -3.41549403, -2.81412012, -2.66202556, -2.40205991, -2.0011362 ,
#          -1.77547079, -1.59638908, -1.57604891, -1.56388427, -1.27469028,
#          -1.11848432, -0.75556872, -0.45317572, -0.30454351, -0.22449511,
#          -0.15107058, -0.13826535, -0.09519137, -0.07045434, -0.06821818,
#           0.06843138,  0.17526447,  0.3346037 ,  0.33880237,  0.39513676,
#           0.44380749,  0.48556974,  0.50669281,  0.62409204,  0.66498238,
#           0.78240517,  0.84320424,  1.00417117,  1.04971477,  1.06061173,
#           1.10307498,  1.14483454,  1.21106167,  1.21177208,  1.23842046,
#           1.3308061 ,  1.4804286 ,  1.48667594,  1.51923363,  1.59372335,
#           1.60918637,  1.69139259,  1.70975503,  1.96991044,  2.17457175,
#           2.3756448 ,  2.4880199 ,  2.49768012,  2.51809393,  3.06363155])),
#  (1.9335019732342729, -0.03848895253439791, 0.962082705040724))

# %%
skew(residuals)
# Out:
# -0.9865673346742722

# %%
#pip install yellowbrick

# %%
from yellowbrick.regressor import ResidualsPlot, PredictionError

# %%
# Instantiate the linear model and visualizer
model = LinearRegression()
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show() ;                # Finalize and render the figure

# %%
model = LinearRegression()
visualizer = PredictionError(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show();                 # Finalize and render the figure

# %%
final_model = LinearRegression()

final_model.fit(X, y)
# Out:
# LinearRegression()

# %%
final_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
final_model

# %%
coeff_df = pd.DataFrame(final_model.coef_, index = X.columns, columns = ["Coefficient"] )

# %%
adv = [[150,20,15]]

# %%
final_model.predict(adv)
# Out:
# array([13.55862413])

# %% [markdown]
# ### <p style="background-color:purple;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 20px;"><b>Multiple Linear Regression</b></p>
